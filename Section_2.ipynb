# %%
""" 
Section 1 - 2026 Grad Colloquium Learning Package
=====================================================
Description: This notebook will help beginner coders open and inspect data - seciton 2 of the accompanying handbook - opening multiple netCDFS

Version History: 22/05/26, written by A.D. & Claude, 11/06/26 A.D. write script

Notes:
"""
# Out:
# ' \nSection 1 - 2026 Grad Colloquium Learning Package\n=====================================================\nDescription: This notebook will help beginner coders open and inspect data - seciton 2 of the accompanying handbook - opening multiple netCDFS\n\nVersion History: 22/05/26, written by A.D. & Claude, 11/06/26 A.D. write script\n\nNotes:\n'

# %%
import xarray as xr         # NetCDF & multi-dimensional data
import pandas as pd          # tabular/CSV data
import numpy as np           # numerical operations
import matplotlib.pyplot as plt  # plotting
from glob import  #global path directory
# Out:
#   Cell In[15], line 5
#     from glob import  #global path directory
#                       ^
# SyntaxError: invalid syntax

# %%
files = glob("*.nc")

files = glob("IDE00326*")

print(f"Found {len(files)} files:")
for f in files:
    print(f)
# Out:
# Found 6 files:
# /g/data/w42/ad1803/2026_Grad_Col/Data/Himawarri/IDE00326.202412311910.nc
# /g/data/w42/ad1803/2026_Grad_Col/Data/Himawarri/IDE00326.202412311940.nc
# /g/data/w42/ad1803/2026_Grad_Col/Data/Himawarri/IDE00326.202412311930.nc
# /g/data/w42/ad1803/2026_Grad_Col/Data/Himawarri/IDE00326.202412311900.nc
# /g/data/w42/ad1803/2026_Grad_Col/Data/Himawarri/IDE00326.202412311950.nc
# /g/data/w42/ad1803/2026_Grad_Col/Data/Himawarri/IDE00326.202412311920.nc

# %%
ds = xr.open_mfdataset( , combine =)

# combine="nested"  → concatenates along a new or existing dimension
# combine="by_coords" → lets xarray figure out alignment automatically
# Out:
# /jobfs/170487940.gadi-pbs/ipykernel_3228259/2393418430.py:1: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   ds = xr.open_mfdataset(files, combine="nested")
# /jobfs/170487940.gadi-pbs/ipykernel_3228259/2393418430.py:1: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = xr.open_mfdataset(files, combine="nested")
# ...

# %% [markdown]
# ### Select one variable and inspect it
